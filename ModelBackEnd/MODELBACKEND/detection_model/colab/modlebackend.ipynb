# %%
# !unzip -q /content/ModleBackEnd.zip

# %%
# !pip install pyngrok

# %%
# !pip install -r /content/requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 479.4/479.4 kB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.8/510.8 kB 45.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.5/828.5 kB 43.8 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall -y protobuf
# !pip install protobuf==3.20.3
# Out:
# Found existing installation: protobuf 6.32.0
# Uninstalling protobuf-6.32.0:
#   Successfully uninstalled protobuf-6.32.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 13.8 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# bigframes 2.19.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# ...

# %%
# !ngrok authtoken 32k1CajdJO92nS5qFnwxiZqVdcp_4FLmwrzFuQLzBhbBF5nrs
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import sys
sys.path.append("/content")

# %%
# -----------------------------
# ngrok 터널 열기
# -----------------------------
from pyngrok import ngrok
public_url = ngrok.connect(8000)
print("Public URL:", public_url)
# Out:
# Public URL: NgrokTunnel: "https://b0df49235e02.ngrok-free.app" -> "http://localhost:8000"

# %%
# -----------------------------
# uvicorn으로 서버 실행
# -----------------------------
# !nohup uvicorn app:app --host 0.0.0.0 --port 8000 --reload> /content/backend.log 2>&1 &

# %%
# 8000번 포트에 프로세스 정상 실행중인지 확인
# !lsof -i:8000
# Out:
# COMMAND  PID USER   FD   TYPE DEVICE SIZE/OFF NODE NAME
# uvicorn 1470 root    3u  IPv4  50758      0t0  TCP *:8000 (LISTEN)
# python3 1476 root    3u  IPv4  50758      0t0  TCP *:8000 (LISTEN)
# python3 1476 root   32u  IPv4 247412      0t0  TCP localhost:8000->localhost:59704 (ESTABLISHED)
# ngrok   1493 root    7u  IPv4 247411      0t0  TCP localhost:59704->localhost:8000 (ESTABLISHED)

# %%
# !kill -9 8378
